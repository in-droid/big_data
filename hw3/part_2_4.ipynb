# %% [markdown]
# # Vicinity of major businesses and attractions (based on pickup/dropoff date-time).

# %%
import dask.dataframe as dd
import pandas as pd
import geopandas as gpd
import pyarrow as pa

OUTPUT_DIR = "home/ivan/FRI/2024-2025/sem2/bd/hw3/data/out"

# %%
taxi_df = dd.read_csv('/home/ivan/FRI/2024-2025/sem2/bd/hw3/data/out/sample_taxi_data.csv')

# %%
buissines = pd.read_csv('../../data/DCA_Legally_Operating_Businesses_geocoded_.csv')

# %%
len(buissines)
# Out:
# 72635

# %%
buissines = buissines.loc[buissines['License Expiration Date'] > '2020-01-01']
len(buissines)
# Out:
# 23866

# %%
attractions = pd.read_excel('/home/ivan/FRI/2024-2025/sem2/bd/hw3/data/New_York_Tourist_Locations.xlsx')
# Out:
# /home/ivan/anaconda3/envs/ids_project2/lib/python3.11/site-packages/openpyxl/worksheet/_reader.py:329: UserWarning: Unknown extension is not supported and will be removed
#   warn(msg)

# %%
# attractions = attractions.sample(frac=0.1)

# %%
attractions
# Out:
#                                           Tourist_Spot  \
# 210                                        Sunset Park
# 309                                  City Ice Pavilion
# 208                              National Park Service
# 244                        Bronx Zoo Treetop Adventure
# 150                                           The Ride
# 7                   American Museum of Natural History
# 162                                     United Nations
# 261                 Saint Augustine's Episcopal Church
# 219      Bank of America Winter Village at Bryant Park
# 337                              Czech Center New York
# 241                                     Gracie Mansion
# 142                               The Met Fifth Avenue
# 318                                      Empire Stores
# 270                                  Hoodwinked Escape
# 16                             Brooklyn Botanic Garden
# 273                                    Adam Yauch Park
# 334                                            Pier 40
# 125                                 Spirit of New York
# 319                             Central Park Bandshell
# 293                                       Grant's Tomb
# 104                     Prospect Park Litchfield Villa
# 73                               Madison Square Garden
# 137                                        The Cyclone
# 342                                Harlem Park to Park
# 76                 Museum at Eldridge Street Synagogue
# 331                                            Pier 45
# 51                                       Gramercy Park
# 12                                    Bateaux New York
# 122                            Socrates Sculpture Park
# 303                           Christie’s Auction House
# 332                      Riverbank State Park Ice Rink
# 272                   Staten Island Supreme Courthouse
# 189                            On Location Tours, Inc.
# 23                                    Calvary Cemetery
# 87   New York Public Library, Stephen A. Schwarzman...
#
#                                                Address Zipcode
# 210  Bet. Fifth and Seventh Aves. and 41st and 44th...   11220
# 309  47-32 32nd Place Queens, NY 11101, Long Island...   11101
# 208  c/o Statue of Liberty National Monument New Yo...   10004
# 244                           Bronx, NY 10460, Fordham   10460
# 150  box office: inside The Gift Shop at 584 Eighth...   10018
# 7    Central Park West at 79th St. Manhattan, NY 10...   10024
# 162  First Ave. at 46th St. Manhattan, NY 10017, Mi...   10017
# 261  290 Henry St Manhattan, NY 10002, Lower East Side   10002
# 219  Bryant Park, 42nd St. and 6th Ave. Manhattan, ...   10018
# 337       321 E 73rd St Manhattan, NY, Upper East Side   10021
# 241  East End Ave Manhattan, NY 10128, Upper East Side   10128
# 142  Fifth Ave. at 82nd St. Manhattan, NY 10028 ,Up...   10028
# 318                 53-83 Water Street NY 11201, DUMBO   11201
# 270       151 W. 116th St. Manhattan, NY 10026, Harlem   10026
# 16   1000 Washington Ave. Brooklyn, NY 11225, Prosp...   11225
# 273  Atlantic Avenue at Columbia Place Brooklyn, NY...   11201
# 334  353 West St Manhattan, NY 10014, Greenwich Vil...   10014
# 125  Pier 61, Chelsea Piers at W. 23rd St. & 12th A...   10011
# 319  Mid-park, 66th to 72nd Sts Manhattan, NY, Cent...   10019
# 293  Riverside Drive and West 122nd Street Manhatta...   10027
# 104  95 Prospect Park West Brooklyn, NY 11215, Park...   11215
# 73      2 Penn Plaza Manhattan, NY 10121, Midtown West   10121
# 137      834 Surf Ave Brooklyn, NY 11224, Coney Island   11224
# 342  mail: 134 W. 118th St., ground fl. Manhattan, ...   10026
# 76   12 Eldridge St. Manhattan, NY 10002, Lower Eas...   10002
# 331  Enter at Christopher St and the West Side High...   10014
# 51   E 20th St to E 21st St bet Gramercy Park West ...   10010
# 12   Pier 61, Chelsea Piers (23rd St. & Hudson Rive...   10011
# 122  32-01 Sculpture Park at Broadway Queens, NY 11...   11106
# 303  20 Rockefeller Plaza New York, NY 10020, Midto...   10020
# 332      679 Riverside Dr. Manhattan, NY 10031, Harlem   10031
# 272  18 Richmond Terrace Staten Island, NY 10301, S...   10301
# 189  Meeting Sites in Midtown Manhattan; mail: 555 ...   10018
# 23   49-02 Laurel Hill Blvd. Queens, NY 11377, Wood...   11377
# 87   Fifth Ave. & 42nd St. Manhattan, NY 10018, Mid...   10018

# %%
from geopy.geocoders import Nominatim
from geopy.extra.rate_limiter import RateLimiter
from geopy.exc import GeocoderTimedOut, GeocoderUnavailable

# Initialize Nominatim geocoder
geolocator = Nominatim(user_agent="event_location_geocoder", timeout=10)
geocode = RateLimiter(geolocator.geocode, min_delay_seconds=1)

def preprocess_location(location):
    # Clean and format the location string
    location = (
        location.replace("between", "&")
        .replace(" and ", " & ")
        .replace("STREET", "St")
        .replace("BOULEVARD", "Blvd")
        .replace("BROADWAY", "Broadway")
        + ", New York, NY"  # Add city/state for better accuracy
    )
    return location

def get_coordinates(location):
    try:
        location = preprocess_location(location)
        result = geocode(location)
        if result:
            return (result.latitude, result.longitude)
        else:
            return (None, None)
    except (GeocoderTimedOut, GeocoderUnavailable):
        return (None, None)


location = "Bronx, NY 10460, Fordham"
print(get_coordinates(location))
# Out:
# (40.863092800000004, -73.89451320075729)

# %%
# Create a DataFrame to store coordinates

attractions[['lat', 'lon']] = attractions['Address'].apply(
    lambda x: pd.Series(get_coordinates(x)))

# %%
attractions
# Out:
#                                           Tourist_Spot  \
# 210                                        Sunset Park
# 309                                  City Ice Pavilion
# 208                              National Park Service
# 244                        Bronx Zoo Treetop Adventure
# 150                                           The Ride
# 7                   American Museum of Natural History
# 162                                     United Nations
# 261                 Saint Augustine's Episcopal Church
# 219      Bank of America Winter Village at Bryant Park
# 337                              Czech Center New York
# 241                                     Gracie Mansion
# 142                               The Met Fifth Avenue
# 318                                      Empire Stores
# 270                                  Hoodwinked Escape
# 16                             Brooklyn Botanic Garden
# 273                                    Adam Yauch Park
# 334                                            Pier 40
# 125                                 Spirit of New York
# 319                             Central Park Bandshell
# 293                                       Grant's Tomb
# 104                     Prospect Park Litchfield Villa
# 73                               Madison Square Garden
# 137                                        The Cyclone
# 342                                Harlem Park to Park
# 76                 Museum at Eldridge Street Synagogue
# 331                                            Pier 45
# 51                                       Gramercy Park
# 12                                    Bateaux New York
# 122                            Socrates Sculpture Park
# 303                           Christie’s Auction House
# 332                      Riverbank State Park Ice Rink
# 272                   Staten Island Supreme Courthouse
# 189                            On Location Tours, Inc.
# 23                                    Calvary Cemetery
# 87   New York Public Library, Stephen A. Schwarzman...
#
#                                                Address Zipcode        lat  \
# 210  Bet. Fifth and Seventh Aves. and 41st and 44th...   11220        NaN
# 309  47-32 32nd Place Queens, NY 11101, Long Island...   11101  40.741485
# 208  c/o Statue of Liberty National Monument New Yo...   10004        NaN
# 244                           Bronx, NY 10460, Fordham   10460  40.863093
# 150  box office: inside The Gift Shop at 584 Eighth...   10018        NaN
# 7    Central Park West at 79th St. Manhattan, NY 10...   10024        NaN
# 162  First Ave. at 46th St. Manhattan, NY 10017, Mi...   10017        NaN
# 261  290 Henry St Manhattan, NY 10002, Lower East Side   10002  40.713275
# 219  Bryant Park, 42nd St. and 6th Ave. Manhattan, ...   10018        NaN
# 337       321 E 73rd St Manhattan, NY, Upper East Side   10021  40.770344
# 241  East End Ave Manhattan, NY 10128, Upper East Side   10128  40.770746
# 142  Fifth Ave. at 82nd St. Manhattan, NY 10028 ,Up...   10028        NaN
# 318                 53-83 Water Street NY 11201, DUMBO   11201  40.703345
# 270       151 W. 116th St. Manhattan, NY 10026, Harlem   10026  40.802628
# 16   1000 Washington Ave. Brooklyn, NY 11225, Prosp...   11225  40.671567
# 273  Atlantic Avenue at Columbia Place Brooklyn, NY...   11201        NaN
# 334  353 West St Manhattan, NY 10014, Greenwich Vil...   10014        NaN
# 125  Pier 61, Chelsea Piers at W. 23rd St. & 12th A...   10011        NaN
# 319  Mid-park, 66th to 72nd Sts Manhattan, NY, Cent...   10019        NaN
# 293  Riverside Drive and West 122nd Street Manhatta...   10027  40.812899
# 104  95 Prospect Park West Brooklyn, NY 11215, Park...   11215  40.657437
# 73      2 Penn Plaza Manhattan, NY 10121, Midtown West   10121        NaN
# 137      834 Surf Ave Brooklyn, NY 11224, Coney Island   11224  40.572769
# 342  mail: 134 W. 118th St., ground fl. Manhattan, ...   10026        NaN
# 76   12 Eldridge St. Manhattan, NY 10002, Lower Eas...   10002  40.714729
# 331  Enter at Christopher St and the West Side High...   10014        NaN
# 51   E 20th St to E 21st St bet Gramercy Park West ...   10010        NaN
# 12   Pier 61, Chelsea Piers (23rd St. & Hudson Rive...   10011        NaN
# 122  32-01 Sculpture Park at Broadway Queens, NY 11...   11106        NaN
# 303  20 Rockefeller Plaza New York, NY 10020, Midto...   10020        NaN
# 332      679 Riverside Dr. Manhattan, NY 10031, Harlem   10031        NaN
# 272  18 Richmond Terrace Staten Island, NY 10301, S...   10301  40.643376
# 189  Meeting Sites in Midtown Manhattan; mail: 555 ...   10018        NaN
# 23   49-02 Laurel Hill Blvd. Queens, NY 11377, Wood...   11377  40.737593
# 87   Fifth Ave. & 42nd St. Manhattan, NY 10018, Mid...   10018        NaN
#
#            lon
# 210        NaN
# 309 -73.933709
# 208        NaN
# 244 -73.894513
# 150        NaN
# 7          NaN
# 162        NaN
# 261 -73.991392
# 219        NaN
# 337 -73.959890
# 241 -73.947830
# 142        NaN
# 318 -73.993404
# 270 -73.951100
# 16  -73.962552
# 273        NaN
# 334        NaN
# 125        NaN
# 319        NaN
# 293 -73.962725
# 104 -73.983150
# 73         NaN
# 137 -73.996639
# 342        NaN
# 76  -73.993461
# 331        NaN
# 51         NaN
# 12         NaN
# 122        NaN
# 303        NaN
# 332        NaN
# 272 -74.076155
# 189        NaN
# 23  -73.904713
# 87         NaN

# %%
buissines.head(2)
# Out:
#    DCA License Number License Type License Expiration Date  License Category  \
# 6         1460055-DCA     Business               3/31/2018  Stoop Line Stand
# 12        1280923-DCA   Individual               9/30/2017    General Vendor
#
#             Business Name Business Name 2 Address Building  \
# 6   LIBERTY PRODUCE, INC.             NaN            12716
# 12        OLIJNYK, STEVEN             NaN                9
#
#    Address Street Name Secondary Address Street Name      Address City  ...  \
# 6            111TH AVE                           NaN  SOUTH OZONE PARK  ...
# 12        MIDLAND GDNS                           NaN        BRONXVILLE  ...
#
#                                                Detail Longitude   Latitude  \
# 6   Product Category: Fruits, Vegetables, Soft Dri... -73.81406  40.682565
# 12                                                NaN       NaN        NaN
#
#    Borough Comminity Board  Census Tract  Council District               NTA  \
# 6   QUEENS           410.0         172.0              28.0  South Ozone Park
# 12     NaN             NaN           NaN               NaN               NaN
#
#              BBL        BIN
# 6   4.116320e+09  4250792.0
# 12           NaN        NaN
#
# [2 rows x 24 columns]

# %%
businesses_gdf = gpd.GeoDataFrame(
        buissines,
        geometry=gpd.points_from_xy(buissines.Longitude, buissines.Latitude),
        crs="EPSG:4326"
    ).to_crs("EPSG:32618") 

attractions_gdf = gpd.GeoDataFrame(
        attractions,
        geometry=gpd.points_from_xy(attractions.lon, attractions.lat),
        crs="EPSG:4326"
    ).to_crs("EPSG:32618")

# %%
def find_nearby_pois(trip_points_gdf, pois_gdf, radius=500):
    """Find points of interest within radius (meters) of trip locations"""
    trip_points_gdf['buffer'] = trip_points_gdf.geometry.buffer(radius)
    joined = gpd.sjoin(
        trip_points_gdf.set_geometry('buffer'),
        pois_gdf,
        how='left',
        predicate='intersects'
    )
    return joined.groupby(level=0).size().rename('nearby_count')

# %%
def process_partition(df_partition, businesses_gdf, attractions_gdf):
    # Convert to GeoDataFrame for pickup locations
    pickup_gdf = gpd.GeoDataFrame(
        df_partition,
        geometry=gpd.points_from_xy(
            df_partition.pickup_longitude, 
            df_partition.pickup_latitude
        ),
        crs="EPSG:4326"
    ).to_crs("EPSG:32618")
    
    # Find nearby businesses and attractions for pickup
    df_partition['pickup_nearby_businesses'] = find_nearby_pois(pickup_gdf, businesses_gdf)
    df_partition['pickup_nearby_attractions'] = find_nearby_pois(pickup_gdf, attractions_gdf)
    
    # Convert to GeoDataFrame for dropoff locations
    dropoff_gdf = gpd.GeoDataFrame(
        df_partition,
        geometry=gpd.points_from_xy(
            df_partition.dropoff_longitude, 
            df_partition.dropoff_latitude
        ),
        crs="EPSG:4326"
    ).to_crs("EPSG:32618")
    
    # Find nearby businesses and attractions for dropoff
    df_partition['dropoff_nearby_businesses'] = find_nearby_pois(dropoff_gdf, businesses_gdf)
    df_partition['dropoff_nearby_attractions'] = find_nearby_pois(dropoff_gdf, attractions_gdf)
    # fill na only these columns
    df_partition['pickup_nearby_businesses'] = df_partition['pickup_nearby_businesses'].fillna(0)
    df_partition['pickup_nearby_attractions'] = df_partition['pickup_nearby_attractions'].fillna(0)
    df_partition['dropoff_nearby_businesses'] = df_partition['dropoff_nearby_businesses'].fillna(0)
    df_partition['dropoff_nearby_attractions'] = df_partition['dropoff_nearby_attractions'].fillna(0)
    
    return df_partition

# %%
# df_taxi = taxi_df.compute()
# process_partition(df_taxi, businesses_gdf, attractions_gdf)

# %%
meta = taxi_df._meta.copy()
meta['pickup_nearby_businesses'] = pd.Series(dtype='int64')
meta['pickup_nearby_attractions'] = pd.Series(dtype='int64')
meta['dropoff_nearby_businesses'] = pd.Series(dtype='int64')
meta['dropoff_nearby_attractions'] = pd.Series(dtype='int64')

# %%
taxi_enriched = taxi_df.map_partitions(
    process_partition,
    businesses_gdf=businesses_gdf,
    attractions_gdf=attractions_gdf,
    meta=meta
)

# %%
taxi_enriched.to_parquet(
    f"{OUTPUT_DIR}/sample_taxi_data_enriched.parquet",
    engine='pyarrow',
    compression='snappy',
    # write_options=pa.parquet.WriteOptions(compression="snappy"),
    # partition_on=['pickup_nearby_businesses', 'pickup_nearby_attractions', 'dropoff_nearby_businesses', 'dropoff_nearby_attractions']
)
taxi_enriched = taxi_enriched.compute()

# %%
taxi_enriched
# Out:
#       vendorid tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0          1.0  2020-01-22 20:10:13   2020-01-22 20:28:03              1.0
# 1          2.0  2020-01-18 23:54:57   2020-01-19 00:04:55              6.0
# 2          1.0  2020-01-04 11:10:51   2020-01-04 11:18:37              3.0
# 3          2.0  2020-01-23 08:05:22   2020-01-23 08:17:23              5.0
# 4          2.0  2020-01-16 17:09:03   2020-01-16 17:12:50              1.0
# ...        ...                  ...                   ...              ...
# 3280       1.0  2024-02-07 19:08:26   2024-02-07 19:08:26              1.0
# 3281       2.0  2024-02-05 11:08:46   2024-02-05 11:30:10              3.0
# 3282       2.0  2024-02-06 14:40:16   2024-02-06 15:15:56              5.0
# 3283       2.0  2024-02-09 18:38:17   2024-02-09 18:41:30              1.0
# 3284       2.0  2024-02-02 10:53:57   2024-02-02 11:09:03              1.0
#
#       trip_distance  ratecodeid store_and_fwd_flag  pulocationid  \
# 0              2.20         1.0                  N           100
# 1              1.96         1.0                  N           264
# 2              1.30         1.0                  N           161
# 3              1.73         1.0                  N           141
# 4              0.93         1.0                  N           263
# ...             ...         ...                ...           ...
# 3280           0.00         1.0                  N           162
# 3281           1.79         1.0                  N           230
# 3282           3.47         1.0                  N           140
# 3283           0.44         1.0                  N           236
# 3284           2.98         1.0                  N           237
#
#       dolocationid  payment_type  ...  airport_fee  year  pickup_latitude  \
# 0              113           1.0  ...          NaN  2020        40.753513
# 1              264           1.0  ...          NaN  2020              NaN
# 2              237           2.0  ...          NaN  2020        40.758028
# 3              162           1.0  ...          NaN  2020        40.766948
# 4              236           1.0  ...          NaN  2020        40.778766
# ...            ...           ...  ...          ...   ...              ...
# 3280           264           2.0  ...          0.0  2024        40.756688
# 3281           233           2.0  ...          0.0  2024        40.759818
# 3282           151           1.0  ...          0.0  2024        40.765484
# 3283           263           1.0  ...          0.0  2024        40.780436
# 3284           166           1.0  ...          0.0  2024        40.768615
#
#       pickup_longitude  dropoff_latitude  dropoff_longitude  \
# 0           -73.988787         40.732579         -73.994305
# 1                  NaN               NaN                NaN
# 2           -73.977698         40.768615         -73.965635
# 3           -73.959635         40.756688         -73.972356
# 4           -73.951010         40.780436         -73.957012
# ...                ...               ...                ...
# 3280        -73.972356               NaN                NaN
# 3281        -73.984196         40.749914         -73.970443
# 3282        -73.954739         40.797962         -73.968168
# 3283        -73.957012         40.778766         -73.951010
# 3284        -73.965635         40.809457         -73.961764
#
#       pickup_nearby_businesses  pickup_nearby_attractions  \
# 0                          193                          1
# 1                            1                          1
# 2                          454                          1
# 3                          123                          1
# 4                          120                          1
# ...                        ...                        ...
# 3280                       130                          1
# 3281                       388                          1
# 3282                        74                          1
# 3283                        89                          1
# 3284                       101                          1
#
#       dropoff_nearby_businesses  dropoff_nearby_attractions
# 0                           111                           1
# 1                             1                           1
# 2                           101                           1
# 3                           130                           1
# 4                            89                           1
# ...                         ...                         ...
# 3280                          1                           1
# 3281                         68                           1
# 3282                         39                           1
# 3283                        120                           1
# 3284                         15                           1
#
# [3285 rows x 28 columns]

# %%
taxi
